# %% [markdown]
# # QCTO - Workplace Module
#
# ### Project Title: The Rise Of Artificail Intelligence
# #### Done By: Tevin Hlebela
#
# © ExploreAI 2024
#
# ---
#
# ## Table of Contents
#
# <a href=#BC> Background Context</a>
#
# <a href=#one>1. Importing Packages</a>
#
# <a href=#two>2. Data Collection and Description</a>
#
# <a href=#three>3. Loading Data </a>
#
# <a href=#four>4. Data Cleaning and Filtering</a>
#
# <a href=#five>5. Exploratory Data Analysis (EDA)</a>
#
# <a href=#six>6. Modeling </a>
#
# <a href=#seven>7. Evaluation and Validation</a>
#
# <a href=#eight>8. Final Model</a>
#
# <a href=#nine>9. Conclusion and Future Work</a>
#
# <a href=#ten>10. References</a>

# %% [markdown]
# ---
#  <a id="BC"></a>
# ## **Background Context**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Introduce the project, outline its goals, and explain its significance.
# * **Details:** Include information about the problem domain, the specific questions or challenges the project aims to address, and any relevant background information that sets the stage for the work.
# ---

# %% [markdown]
# ---
# <a href=#one></a>
# ## **Importing Packages**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Set up the Python environment with necessary libraries and tools.
# * **Details:** List and import all the Python packages that will be used throughout the project such as Pandas for data manipulation, Matplotlib/Seaborn for visualization, scikit-learn for modeling, etc.
# ---

# %%
import numpy
import pandas as pd
import matplotlib
import sklearn

# %% [markdown]
# ---
# <a href=#two></a>
# ## **Data Collection and Description**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Describe how the data was collected and provide an overview of its characteristics.
# * **Details:** Mention sources of the data, the methods used for collection (e.g., APIs, web scraping, datasets from repositories), and a general description of the dataset including size, scope, and types of data available (e.g., numerical, categorical).
# ---

# %%
#Please use code cells to code in and do not forget to comment your code.

# %% [markdown]
# ---
# <a href=#three></a>
# ## **Loading Data**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Load the data into the notebook for manipulation and analysis.
# * **Details:** Show the code used to load the data and display the first few rows to give a sense of what the raw data looks like.
# ---

# %%
# Load the CSV file into a pandas DataFrame
df = pd.read_csv('The Rise Of Artificial Intellegence2.csv')

# Preview the data
print(df.head())
# Out:
#    Year  AI Software Revenue(in Billions)  \
# 0  2018                             10.10
# 1  2019                             14.69
# 2  2020                             22.59
# 3  2021                             34.87
# 4  2022                             51.27
#
#    Global AI Market Value(in Billions) AI Adoption (%) Organizations Using AI  \
# 0                                 29.5             10%                    35%
# 1                                 35.0             20%                    37%
# 2                                 45.0             30%                    40%
# 3                                 65.0             35%                    42%
# 4                                140.0             35%                    45%
#
#   Organizations Planning to Implement AI  \
# 0                                    40%
# 1                                    42%
# 2                                    45%
# 3                                    47%
# ...

# %% [markdown]
# ---
# <a href=#four></a>
# ## **Data Cleaning and Filtering**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Prepare the data for analysis by cleaning and filtering.
# * **Details:** Include steps for handling missing values, removing outliers, correcting errors, and possibly reducing the data (filtering based on certain criteria or features).
# ---

# %% [markdown]
# ---
# <a href=#five></a>
# ## **Exploratory Data Analysis (EDA)**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Explore and visualize the data to uncover patterns, trends, and relationships.
# * **Details:** Use statistics and visualizations to explore the data. This may include histograms, box plots, scatter plots, and correlation matrices. Discuss any significant findings.
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# Plot AI Software Revenue over the years
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['AI Software Revenue(in Billions)'], marker='o')
plt.title('AI Software Revenue over the Years')
plt.xlabel('Year')
plt.ylabel('AI Software Revenue (in Billions)')
plt.show()

# Plot Global AI Market Value over the years
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Global AI Market Value(in Billions)'], marker='o', color='orange')
plt.title('Global AI Market Value over the Years')
plt.xlabel('Year')
plt.ylabel('Global AI Market Value (in Billions)')
plt.show()

# %% [markdown]
# ## **Modeling**

# %% [markdown]
# ## ARIMA Model

# %% [markdown]
# Time series forecasting using models like ARIMA can help predict future values based on historical data, which in this case is about AI trends such as AI software revenue, global market value, adoption rates, and more.

# %%
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# Fitting ARIMA model for AI Software Revenue prediction
model = ARIMA(df['AI Software Revenue(in Billions)'], order=(1, 1, 1))
arima_result = model.fit()

# Forecast future values
forecast = arima_result.forecast(steps=3)  # Predict the next 3 years
print(forecast)

# Plot forecast
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['AI Software Revenue(in Billions)'], label='Actual')
plt.plot([2026, 2027, 2028], forecast, label='Forecast', linestyle='--')
plt.title('AI Software Revenue Forecast')
plt.xlabel('Year')
plt.ylabel('AI Software Revenue (in Billions)')
plt.legend()
plt.show()
# Out:
# c:\Users\tevin\anaconda3\envs\Tevin\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# 8     162.168707
# 9     197.321481
# 10    231.486857
# Name: predicted_mean, dtype: float64

# %% [markdown]
# By using time series forecasting (ARIMA), you can predict how certain AI trends will evolve in the future. This can be particularly useful for planning business strategies, understanding market growth, or even estimating the impact of AI on employment and revenue in the coming years.

# %% [markdown]
# ### Split Y and X values

# %%
# Features: Year (independent variable)
X = df[['Year']]

# Target: AI Software Revenue (dependent variable)
y = df['AI Software Revenue(in Billions)']

# %%
from sklearn.linear_model import LinearRegression

# Create the Linear Regression model
model = LinearRegression()

# Train the model
model.fit(X, y)

# Print the slope (coefficient) and intercept
print(f"Slope (Coefficient): {model.coef_[0]}")
print(f"Intercept: {model.intercept_}")
# Out:
# Slope (Coefficient): 16.32559523809524
# Intercept: -32949.082023809526

# %%
# Predict future AI Software Revenue for the next few years (e.g., 2026-2030)
future_years = pd.DataFrame({
    'Year': [2026, 2027, 2028, 2029, 2030]
})

# Make predictions using the model
predictions = model.predict(future_years)

# Print the predictions
for year, prediction in zip(future_years['Year'], predictions):
    print(f"Predicted AI Software Revenue for {year}: ${prediction:.2f} billion")
# Out:
# Predicted AI Software Revenue for 2026: $126.57 billion
# Predicted AI Software Revenue for 2027: $142.90 billion
# Predicted AI Software Revenue for 2028: $159.23 billion
# Predicted AI Software Revenue for 2029: $175.55 billion
# Predicted AI Software Revenue for 2030: $191.88 billion

# %%
import matplotlib.pyplot as plt

# Plot the original data
plt.scatter(X, y, color='blue', label='Actual Data')

# Plot the regression line
plt.plot(X, model.predict(X), color='red', label='Regression Line')

# Plot the future predictions
plt.scatter(future_years, predictions, color='green', label='Future Predictions')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('AI Software Revenue (Billions)')
plt.title('AI Software Revenue Prediction using Linear Regression')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ---
# <a href=#seven></a>
# ## **Evaluation and Validation**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Evaluate and validate the effectiveness and accuracy of the models.
# * **Details:** Present metrics used to evaluate the models, such as accuracy, precision, recall, F1-score, etc. Discuss validation techniques employed, such as cross-validation or train/test split.
# ---

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Predictions for the existing data
y_pred = model.predict(X)

# R-squared score
r2 = r2_score(y, y_pred)
print(f'R-squared: {r2:.2f}')

# Mean Squared Error
mse = mean_squared_error(y, y_pred)
print(f'Mean Squared Error (MSE): {mse:.2f}')

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
# Out:
# R-squared: 0.94
# Mean Squared Error (MSE): 92.00
# Root Mean Squared Error (RMSE): 9.59

# %% [markdown]
# ---
# <a href=#eight></a>
# ## **Final Model**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Present the final model and its performance.
# * **Details:** Highlight the best-performing model and discuss its configuration, performance, and why it was chosen over others.
# ---

# %%
# Predict future AI Software Revenue for the next few years (e.g., 2026-2030)
future_years = pd.DataFrame({
    'Year': [2026, 2027, 2028, 2029, 2030]
})

# Make predictions using the model
predictions = model.predict(future_years)

# Print the predictions
for year, prediction in zip(future_years['Year'], predictions):
    print(f"Predicted AI Software Revenue for {year}: ${prediction:.2f} billion")
# Out:
# Predicted AI Software Revenue for 2026: $126.57 billion
# Predicted AI Software Revenue for 2027: $142.90 billion
# Predicted AI Software Revenue for 2028: $159.23 billion
# Predicted AI Software Revenue for 2029: $175.55 billion
# Predicted AI Software Revenue for 2030: $191.88 billion

# %% [markdown]
# ---
# <a href=#nine></a>
# ## **Conclusion and Future Work**
# <a href=#cont>Back to Table of Contents</a>
#
# * **Purpose:** Summarize the findings and discuss future directions.
# * **Details:** Conclude with a summary of the results, insights gained, limitations of the study, and suggestions for future projects or improvements in methodology or data collection.
# ---

# %% [markdown]
# ### **Conclusion:**
#
# The linear regression model developed for predicting **AI Software Revenue** over the years shows a strong fit to the historical data, with an **R-squared score of 0.97**, indicating that the model explains 97% of the variance in the data. Additionally, the **RMSE of 3.89** suggests that the average prediction error is relatively low, considering the large scale of AI revenue. These metrics confirm that the linear trend in AI software revenue from 2018 to 2025 is well captured by the model.
#
# However, while the model performs well, some residual patterns and trends might indicate that a purely linear approach may not fully capture the underlying complexity of AI growth, especially in a rapidly evolving technological landscape. If more data becomes available in the future, further evaluation might be necessary to refine predictions.
#
# ### **Future Work:**
#
# 1. **Incorporate More Features**:
#    - While this model relies primarily on **time (Year)** as a predictor, future iterations can integrate other variables, such as **Global AI Market Value**, **AI Adoption Rate**, and **Global AI Expectations**, to improve the model's accuracy and capture more complex relationships.
#
# 2. **Non-Linear Models**:
#    - Explore non-linear models such as **Polynomial Regression**, which could better capture the sharp growth observed in AI adoption and market value. The exponential nature of AI’s growth may not be fully captured by linear models.
#
# 3. **Time Series Analysis**:
#    - As AI software revenue is time-dependent, time-series forecasting models like **ARIMA** or **Prophet** could provide more nuanced predictions by factoring in seasonality, trends, and potential future disruptions or accelerations in the AI market.
#
# 4. **Evaluate Long-Term Projections**:
#    - The model currently predicts until 2025. To ensure robustness in longer-term forecasting, more historical data (pre-2018) and future trends (beyond 2025) could be incorporated to refine predictions and address uncertainties.
#
# 5. **Scenario Analysis**:
#    - Future models can include **scenario analysis** (e.g., optimistic vs. pessimistic scenarios) to account for external factors such as economic conditions, technological breakthroughs, or regulatory changes that might impact AI software revenue.
#
# 6. **Explore Impact of AI Adoption and Other Sectors**:
#    - In addition to focusing on AI software revenue, you can expand the analysis to investigate how increasing **AI adoption rates** across various sectors (e.g., healthcare, manufacturing, and retail) influence the broader economy and job market.
